# %%
import pandas as pd
import numpy as np
import sqlite3
import torch

# %%
# Load dataset
con = sqlite3.connect('../paper_data.sqlite3')
papers = pd.read_sql_query("SELECT * FROM paper_data", con)

con.close()

# %%
# paper.drop(columns=['file_name'], inplace=True)
papers
# Out:
#                                                    title  \
# 0      Association between leukocyte telomere length ...
# 1      Molecular insights into inclusion complexes of...
# 2      Characterization and enumeration of complement...
# 3      An environmental-semantic computing system for...
# 4      Crystallisation of CH3NH3PbX3 (X = I, Br, and ...
# ...                                                  ...
# 20211  Titania nanotube architectures synthesized on ...
# 20212  Effect of molecular weight on mechanical prope...
# 20213  Development and validation of HERWIG 7 tunes f...
# 20214  Peak-dose ballism associated with declining im...
# 20215  Bioaccessibility and antioxidant activity of p...
#
#                                              description  year   coverdate  \
# 0      Aim: The aims of this study were to compare le...  2018  2018-01-01
# 1      The structural dynamics and stability of inclu...  2018  2018-01-01
# 2      Abelian codes and complementary dual codes for...  2018  2018-10-01
# 3      Environmental-semantic space integration is a ...  2018  2018-01-01
# 4      In this work, the effects of halides on the pr...  2018  2018-04-01
# ...                                                  ...   ...         ...
# 20211  The aim of this study is to synthesize Titania...  2021  2021-11-01
# 20212  Molecular weight (MW) is an important factor t...  2021  2021-01-01
# 20213  This paper presents new sets of parameters (“t...  2021  2021-04-01
# 20214                                                     2021  2021-01-01
# 20215  Encapsulation technique was applied to improve...  2021  2021-11-01
#
#                                         publication_name citation_count  \
# 0            International Journal of Rheumatic Diseases             21
# 1            Journal of Molecular Graphics and Modelling             18
# 2           Journal of Applied Mathematics and Computing              9
# 3      Frontiers in Artificial Intelligence and Appli...              3
# 4                                 Micro and Nano Letters              5
# ...                                                  ...            ...
# 20211                                          Materials              5
# 20212                       Materials Today: Proceedings              9
# 20213                        European Physical Journal C             10
# 20214                      Journal of Movement Disorders              0
# 20215                                     Food Chemistry             17
#
#                                            subject_areas  \
# 0                                           Rheumatology
# 1      Spectroscopy,Physical and Theoretical Chemistr...
# 2          Computational Mathematics,Applied Mathematics
# 3                                Artificial Intelligence
# 4      Bioengineering,Biomedical Engineering,Material...
# ...                                                  ...
# 20211   Materials Science (all),Condensed Matter Physics
# 20212                            Materials Science (all)
# 20213  Engineering (miscellaneous),Physics and Astron...
# 20214                     Neurology (clinical),Neurology
# 20215                  Analytical Chemistry,Food Science
#
#                                             author_names  \
# 0      Poonpet T.,Saetan N.,Tanavalee A.,Wilairatana ...
# 1      Mahalapbutr P.,Nutho B.,Wolschann P.,Chavasiri...
# 2                   Boripan A.,Jitman S.,Udomkavanich P.
# 3      Kiyoki Y.,Chen X.,Veesommai C.,Sasaki S.,Uraki...
# 4      Loryuenyong V.,Khiaokaeo N.,Koomsin W.,Thongch...
# ...                                                  ...
# 20211  Chunate H.-T.,Khamwannah J.,Aliyu A.A.A.,Tanta...
# 20212        Promnil S.,Numpaisal P.-O.,Ruksakulpiwat Y.
# 20213  Sirunyan A.M.,Tumasyan A.,Adam W.,Ambrogi F.,B...
# 20214  Jen-Rei D.C.,Thien L.T.,Keong L.H.,Leng H.W.,P...
# 20215   Peanparkdee M.,Borompichaichartkul C.,Iwamoto S.
#
#                                             affiliations  \
# 0                               Chulalongkorn University
# 1      Chulalongkorn University,Universität Wien,Chia...
# 2          Chulalongkorn University,Silpakorn University
# 3      Chulalongkorn University,Keio University,Kanag...
# 4          Chulalongkorn University,Silpakorn University
# ...                                                  ...
# 20211         Chulalongkorn University,Meticuly Co. Ltd.
# 20212  Suranaree University of Technology,Center of E...
# 20213  Rheinisch-Westfälische Technische Hochschule A...
# 20214  Hospital Pulau Pinang,Penang Hospital,King Chu...
# 20215  Chulalongkorn University,Faculty of Applied Bi...
#
#                                                countries        filename
# 0                                               Thailand  201802787.json
# 1                                       Austria,Thailand  201802729.json
# 2                                               Thailand  201800578.json
# 3                                         Japan,Thailand  201802213.json
# 4                                               Thailand  201801616.json
# ...                                                  ...             ...
# 20211                                           Thailand  202100632.json
# 20212                                           Thailand  202103246.json
# 20213  Uzbekistan,Turkey,Taiwan,Poland,Estonia,Belaru...  202102288.json
# 20214                                  Thailand,Malaysia  202103378.json
# 20215                                     Japan,Thailand  202100729.json
#
# [20216 rows x 11 columns]

# %%
# Search for empty strings in every string column and replace them with NaN
str_cols = papers.select_dtypes(include=['object']).columns

for col in str_cols:
    papers[col] = papers[col].replace('', np.nan)

papers.isna().sum()
# Out:
# title                 1
# description         665
# year                  0
# coverdate             0
# publication_name      0
# citation_count        0
# subject_areas         0
# author_names          0
# affiliations          0
# countries             0
# filename              0
# dtype: int64

# %%
papers.dropna(subset=['title', 'description'], inplace=True)

# %%
papers.loc[papers.citation_count == 'None', 'citation_count'] = np.nan
papers['citation_count'] = pd.to_numeric(papers['citation_count'], errors='coerce')

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
papers['citation_count'] = imputer.fit_transform(papers[['citation_count']])

papers['coverdate'] = pd.to_datetime(papers['coverdate'], errors='coerce')
# Out:
# array(['Rheumatology',
#        'Spectroscopy,Physical and Theoretical Chemistry,Computer Graphics and Computer-Aided Design,Materials Chemistry',
#        'Computational Mathematics,Applied Mathematics', ...,
#        'Immunology and Allergy,Immunology,Toxicology,Pharmacology',
#        'Computer Networks and Communications,Instrumentation',
#        'Dermatology,Obstetrics and Gynecology,Infectious Diseases'],
#       shape=(3063,), dtype=object)

# %%
subject_areas = papers.subject_areas.str.split(',').explode().str.strip().unique().tolist()

#Get number of authors per paper
papers['author_count'] = papers.author_names.str.split(',').apply(lambda x: len(x) if isinstance(x, list) else 0)
papers['affil_count'] = papers.affiliations.str.split(',').apply(lambda x: len(x) if isinstance(x, list) else 0)
papers['country_count'] = papers.countries.str.split(',').apply(lambda x: len(x) if isinstance(x, list) else 0)
# Out:
#                                                title  \
# 0  Association between leukocyte telomere length ...
# 1  Molecular insights into inclusion complexes of...
# 2  Characterization and enumeration of complement...
# 3  An environmental-semantic computing system for...
# 4  Crystallisation of CH3NH3PbX3 (X = I, Br, and ...
#
#                                          description  year  coverdate  \
# 0  Aim: The aims of this study were to compare le...  2018 2018-01-01
# 1  The structural dynamics and stability of inclu...  2018 2018-01-01
# 2  Abelian codes and complementary dual codes for...  2018 2018-10-01
# 3  Environmental-semantic space integration is a ...  2018 2018-01-01
# 4  In this work, the effects of halides on the pr...  2018 2018-04-01
#
#                                     publication_name  citation_count  \
# 0        International Journal of Rheumatic Diseases            21.0
# 1        Journal of Molecular Graphics and Modelling            18.0
# 2       Journal of Applied Mathematics and Computing             9.0
# 3  Frontiers in Artificial Intelligence and Appli...             3.0
# 4                             Micro and Nano Letters             5.0
#
#                                        subject_areas  \
# 0                                       Rheumatology
# 1  Spectroscopy,Physical and Theoretical Chemistr...
# 2      Computational Mathematics,Applied Mathematics
# 3                            Artificial Intelligence
# 4  Bioengineering,Biomedical Engineering,Material...
#
#                                         author_names  \
# 0  Poonpet T.,Saetan N.,Tanavalee A.,Wilairatana ...
# 1  Mahalapbutr P.,Nutho B.,Wolschann P.,Chavasiri...
# 2               Boripan A.,Jitman S.,Udomkavanich P.
# 3  Kiyoki Y.,Chen X.,Veesommai C.,Sasaki S.,Uraki...
# 4  Loryuenyong V.,Khiaokaeo N.,Koomsin W.,Thongch...
#
#                                         affiliations         countries  \
# 0                           Chulalongkorn University          Thailand
# 1  Chulalongkorn University,Universität Wien,Chia...  Austria,Thailand
# 2      Chulalongkorn University,Silpakorn University          Thailand
# 3  Chulalongkorn University,Keio University,Kanag...    Japan,Thailand
# 4      Chulalongkorn University,Silpakorn University          Thailand
#
#          filename  author_counts  author_count  affil_count  country_count
# 0  201802787.json              6             6            1              1
# 1  201802729.json              6             6            3              2
# 2  201800578.json              3             3            2              1
# 3  201802213.json              8             8            3              2
# 4  201801616.json              5             5            2              1
